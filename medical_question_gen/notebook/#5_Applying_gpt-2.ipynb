# %% [markdown]
# # AstractGen: Applying gpt-2
#
# 이 포스트는 6개로 이루어진 "AbstractGEN"의 마지막 포스트입니다. 이번 포스트에서는 gpt-2를 파인튜닝해 논문 초록을 생성해보겠습니다.
#
# gpt-2는 문장 생성 분야에 있어서는 최대의 성능을 내는 것으로 알려져 있습니다.
#
# 본 포스트에서는 gpt-2의 구조에 대해 다루지 않습니다. 해당 내용은 [이곳](https://)을 참조하세요!
#
# 앞으로의 포스트는 다음과 같습니다:
#
# 0. AbstractGEN: DataAnalysis
# 1. AbstractGEN: Char-level RNN
# 2. AbstractGEN: Word-level RNN
# 3. AbstractGEN: Seq2seq
# 4. AbstractGEN: Seq2seq with attention+teaching force
# 5. **AbstractGEN: Applying gpt-2**

# %%
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .
# !pip install -r ./examples/requirements.txt
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 19005 (delta 2), reused 2 (delta 0), pack-reused 18995
# Receiving objects: 100% (19005/19005), 11.20 MiB | 29.64 MiB/s, done.
# Resolving deltas: 100% (13992/13992), done.
# /content/transformers
# Processing /content/transformers
# ...
#      |████████████████████████████████| 3.1MB 4.6MB/s
# ...
#      |████████████████████████████████| 1.0MB 53.1MB/s
# ...
#      |████████████████████████████████| 870kB 58.6MB/s
# ...
#   Created wheel for transformers: filename=transformers-2.3.0-cp36-none-any.whl size=475153 sha256=b6c06ca4d54d42287a21ed5f056891bdc17b14b4348fceb95463273d505ce936
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i71oh2_f/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# ...

# %%
TRAIN_FILE= "/content/titles_and_abstracts.txt"
TEST_FILE= "/content/abstract_test_2000.txt"

# !python /content/transformers/examples/run_lm_finetuning.py \
    --output_dir=fintuned_lm/ \
    --model_type=gpt2 \
    --model_name_or_path=gpt2 \
    --do_train \
    --train_data_file=$TRAIN_FILE \
    --do_eval \
    --eval_data_file=$TEST_FILE
# Out:
# 01/31/2020 06:33:36 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/31/2020 06:33:36 - INFO - filelock -   Lock 139821217112016 acquired on /root/.cache/torch/transformers/4be02c5697d91738003fb1685c9872f284166aa32e061576bbe6aaeb95649fcf.085d5f6a8e7812ea05ff0e6ed0645ab2e75d80387ad55c1ad9806ee70d272f80.lock
# 01/31/2020 06:33:36 - INFO - transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-config.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpxn311e5y
# Downloading: 100% 176/176 [00:00<00:00, 137kB/s]
# 01/31/2020 06:33:36 - INFO - transformers.file_utils -   storing https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-config.json in cache at /root/.cache/torch/transformers/4be02c5697d91738003fb1685c9872f284166aa32e061576bbe6aaeb95649fcf.085d5f6a8e7812ea05ff0e6ed0645ab2e75d80387ad55c1ad9806ee70d272f80
# ...

# %% [markdown]
# 비교를 위해 논문 제목/초록 데이터로 파인튜닝을 시키지 않을 때의 결과를 먼저 확인했습니다.

# %%
# !python /content/transformers/examples/run_generation.py \
    --model_type=gpt2 \
    --length=50\
    --model_name_or_path=gpt2
# Out:
# 01/31/2020 06:44:45 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-vocab.json from cache at /root/.cache/torch/transformers/f2808208f9bec2320371a9f5f891c184ae0b674ef866b79c58177067d15732dd.1512018be4ba4e8726e41b9145129dc30651ea4fec86aa61f4b9f40bf94eac71
# 01/31/2020 06:44:45 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-merges.txt from cache at /root/.cache/torch/transformers/d629f792e430b3c76a1291bb2766b0a047e36fae0588f9dbc1ae51decdff691b.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 01/31/2020 06:44:46 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-config.json from cache at /root/.cache/torch/transformers/4be02c5697d91738003fb1685c9872f284166aa32e061576bbe6aaeb95649fcf.085d5f6a8e7812ea05ff0e6ed0645ab2e75d80387ad55c1ad9806ee70d272f80
# ...

# %% [markdown]
# 파인튜닝한 결과는 다음과 같습니다.

# %%
# !python /content/transformers/examples/run_generation.py \
    --model_type=gpt2 \
    --length=200\
    --model_name_or_path='/content/transformers/fintuned_lm'
# Out:
# 01/31/2020 06:45:06 - INFO - transformers.tokenization_utils -   Model name '/content/transformers/fintuned_lm' not found in model shortcut name list (gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2). Assuming '/content/transformers/fintuned_lm' is a path, a model identifier, or url to a directory containing tokenizer files.
# 01/31/2020 06:45:06 - INFO - transformers.tokenization_utils -   Didn't find file /content/transformers/fintuned_lm/added_tokens.json. We won't load it.
# 01/31/2020 06:45:06 - INFO - transformers.tokenization_utils -   loading file /content/transformers/fintuned_lm/vocab.json
# 01/31/2020 06:45:06 - INFO - transformers.tokenization_utils -   loading file /content/transformers/fintuned_lm/merges.txt
# 01/31/2020 06:45:06 - INFO - transformers.tokenization_utils -   loading file None
# 01/31/2020 06:45:06 - INFO - transformers.tokenization_utils -   loading file /content/transformers/fintuned_lm/special_tokens_map.json
# ...
